# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# SQL: Subqueries
#
# </p>
# </div>
#
# Data Science Cohort Live NYC Feb 2022
# <p>Phase 1: Topic 6</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="Images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %% [markdown]
# Remember:
#
# SELECT queries return a new table.

# %% [markdown]
# Sometimes:
#
# - Query a table.
# - Filter/select/... on that query
# - Return result of querying on the first query.
#
# First query is a **subquery**.

# %% [markdown]
# Let's get into it with our handy dandy flights database!

# %%
import sqlite3
import numpy as np
import pandas as pd

# connect to flights database
con = sqlite3.connect('data/flights.db')

# %% [markdown]
# Subqueries can be used to great effect in a variety of circumstances:
#
# - Selecting from a table created by a subquery
#     - Subquery in FROM statement
# - Filtering on a subquery.
#     - Subquery in a WHERE statement
# - Filtering in a SELECT statement.

# %% [markdown]
# Example of a query containing a subquery:
#
# Get the average of the highest altitude airports in United States, Russia, and China:
#
# - Select airport name, city, and altitude for the highest airport in each country
# - Then filter this on the country.
# - Then get the average of the altitudes of the resultant airports.
#
# Step by step.

# %%
# %%capture subquery
pd.read_sql("""

SELECT name, 
     city,
     country,
     MAX(CAST(altitude as float)) AS max_altitude
     
     FROM airports
     
     GROUP BY country
     

""", con)

# %%
subquery()
# Out:
#                 name         city         country  max_altitude
# 0        FOB Sharana       Sharan     Afghanistan        7400.0
# 1       Tirana Rinas       Tirana         Albania         126.0
# 2        Tamanrasset  Tamanrasset         Algeria        4518.0
# 3    Fitiuta Airport   Fiti\\'uta  American Samoa         110.0
# 4            Lubango      Lubango          Angola        5778.0
# ..               ...          ...             ...           ...
# 235        Jerusalem    Jerusalem       West Bank        2485.0
# 236    Smara Airport        Smara  Western Sahara         350.0
# 237       Sanaa Intl        Sanaa           Yemen        7216.0
# 238          Kasompe      Kasompe          Zambia        4636.0
# 239      Harare Intl       Harare        Zimbabwe        4887.0
#
# [240 rows x 4 columns]

# %% [markdown]
# This is a table produced by the query. We now want to filter this table on country.
#
# - Can select FROM results of above table and filter WHERE conditon is true.
# - Subquery creates intermediate table for us.

# %%
# %%capture query

pd.read_sql("""

SELECT *
    
FROM 

(SELECT name, 
     city,
     country,
     MAX(CAST(altitude as float)) AS max_altitude
     
     FROM airports
     
     GROUP BY country
     
     ) AS high_alt_airp
     
 WHERE high_alt_airp.country IN ("United States", "Russia", "China")



""", con)

# %%
query()
# Out:
#               name       city        country  max_altitude
# 0  Yading Daocheng   Daocheng          China       14472.0
# 1        Irkutsk-2    Irkutsk         Russia       13411.0
# 2        Silverton  Silverton  United States        9308.0

# %% [markdown]
# Now I select the mean altitude across the three countries.

# %%
# %%capture query

pd.read_sql("""

SELECT AVG(high_alt_airp.max_altitude) AS max_altitude_avg
    
FROM 

(SELECT name, 
     city,
     country,
     MAX(CAST(altitude as float)) AS max_altitude
     
     FROM airports
     
     GROUP BY country
     
     ) AS high_alt_airp
     
 WHERE high_alt_airp.country IN ("United States", "Russia", "China")



""", con)

# %%
# Average altitude of the highest airports in Russia, United States, and China
query()
# Out:
#    max_altitude_avg
# 0           12397.0

# %% [markdown]
# One can create, in principle, a new table of derived columns and do selections and filtering on that new table.
#
# Let's take a look at our routes table again.

# %%
pd.read_sql("""

SELECT * 
     FROM routes
     LIMIT 5


""", con)
# Out:
#    index airline airline_id source source_id dest dest_id codeshare stops  \
# 0      0      2B        410    AER      2965  KZN    2990      None     0
# 1      1      2B        410    ASF      2966  KZN    2990      None     0
# 2      2      2B        410    ASF      2966  MRV    2962      None     0
# 3      3      2B        410    CEK      2968  KZN    2990      None     0
# 4      4      2B        410    CEK      2968  OVB    4078      None     0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# For each airport I want:
# - the count of routes that leaves from there.
# - the count of routes that arrive there.
#
# Many ways to do this. But I'll make full use of subqueries and joins here.

# %%
departure_table = pd.read_sql("""

SELECT source, COUNT(source) as departure_count
     FROM routes
     
     GROUP BY source
     
""", con)

# %%
departure_table
# Out:
#      source  departure_count
# 0       AAE                9
# 1       AAL               20
# 2       AAN                2
# 3       AAQ                3
# 4       AAR                8
# ...     ...              ...
# 3404    ZUH               60
# 3405    ZUM                2
# 3406    ZVK                3
# 3407    ZYI               15
# 3408    ZYL                4
#
# [3409 rows x 2 columns]

# %%
arrival_table = pd.read_sql("""

SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     
     GROUP BY dest
     
""", con)

# %%
arrival_table
# Out:
#      dest  arrival_count
# 0     AAE              9
# 1     AAL             21
# 2     AAN              2
# 3     AAQ              3
# 4     AAR              8
# ...   ...            ...
# 3413  ZUH             59
# 3414  ZUM              2
# 3415  ZVK              3
# 3416  ZYI             15
# 3417  ZYL              6
#
# [3418 rows x 2 columns]

# %% [markdown]
# We can link these the arrival tables and destination tables together:
# - Keep records where source and destination are in both tables.
# - What operation?

# %% [markdown]
# INNER JOIN ON SUBQUERY RESULTS!

# %%
# %%capture full_result

pd.read_sql("""

SELECT dep.source AS airport_code,
        dep.departure_count,
        arriv.arrival_count 
        
FROM

(SELECT source, COUNT(source) as departure_count
     FROM routes
     
     GROUP BY source) AS dep

INNER JOIN 

(SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     
     GROUP BY dest) AS arriv

ON dep.source = arriv.dest
     
""", con)

# %%
full_result()
# Out:
#      airport_code  departure_count  arrival_count
# 0             AAE                9              9
# 1             AAL               20             21
# 2             AAN                2              2
# 3             AAQ                3              3
# 4             AAR                8              8
# ...           ...              ...            ...
# 3397          ZUH               60             59
# 3398          ZUM                2              2
# 3399          ZVK                3              3
# 3400          ZYI               15             15
# 3401          ZYL                4              6
#
# [3402 rows x 3 columns]

# %% [markdown]
# This result is a derived table telling us useful information for each airport and keeping relevant records.
#
# - We can filter or aggregate on this derived table as we see fit.
#
#
# - Get all airports with high amount of routes servicing it:
#     - departure and arrival count both greater than 100.
# - Order by arrival and then deperature count both in descending order.
#
# Help this hapless data science instructor out!

# %%
# %%capture filtered_result

pd.read_sql("""

SELECT dep.source AS airport_code,
        dep.departure_count,
        arriv.arrival_count 
        
FROM

(SELECT source, COUNT(source) as departure_count
     FROM routes
     
     GROUP BY source) AS dep

INNER JOIN 

(SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     
     GROUP BY dest) AS arriv

ON dep.source = arriv.dest
     
""", con)

# %%
filtered_result()

# %% [markdown]
# - Complex as subqueries pile on.
# - There are ways to organize subqueries: common table expressions
# - Will make code readable.
#
# But first: other ways subqueries can be used.

# %% [markdown]
# #### Subqueries in the WHERE statement
#
# - Can use the result of a subquery to filter another selection.
#
# I want all route records where the departure airport has a departure route count greater than 200.

# %%
# %%capture where_subquery1
pd.read_sql('''


SELECT *
            
FROM routes

WHERE source IN (SELECT source 
     FROM routes
     GROUP BY source
     HAVING COUNT(source) > 200) 
''', con)

# %%
where_subquery1()
# Out:
#        index airline airline_id source source_id dest dest_id codeshare stops  \
# 0          5      2B        410    DME      4029  KZN    2990      None     0
# 1          6      2B        410    DME      4029  NBC    6969      None     0
# 2          7      2B        410    DME      4029  TGK      \N      None     0
# 3          8      2B        410    DME      4029  UUA    6160      None     0
# 4        123      2L       2750    ZRH      1678  BDS    1506      None     0
# ...      ...     ...        ...    ...       ...  ...     ...       ...   ...
# 21698  67646      ZL       4178    SYD      3361  OAG    6793      None     0
# 21699  67647      ZL       4178    SYD      3361  PKE    6317      None     0
# 21700  67648      ZL       4178    SYD      3361  TRO    6794      None     0
# 21701  67649      ZL       4178    SYD      3361  WGA    3363      None     0
# 21702  67659      ZM      19016    DME      4029  FRU    2912      None     0
#
#       equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           100
# ...         ...
# 21698       SF3
# 21699       SF3
# 21700       SF3
# 21701       SF3
# 21702       734
#
# [21703 rows x 10 columns]

# %% [markdown]
# Subquerying made this query possible.
#
# #### The Semijoin
#
# - Using a subquery from one table to filter another table.
#
# Example:
#
# Get the airport name, code, country, and altitude for airports with more than 200 routes originating from that airport.

# %%
# %%capture semijoin
pd.read_sql('''

SELECT *
FROM airports

WHERE code IN (
SELECT source 
     FROM routes
     GROUP BY source
     HAVING COUNT(source) > 300 
)
''', con)

# %%
semijoin()
# Out:
#     index    id                             name               city  \
# 0     191   193            Lester B Pearson Intl            Toronto
# 1     299   302                    Brussels Natl           Brussels
# 2     337   340                   Frankfurt Main          Frankfurt
# 3     343   346              Franz Josef Strauss             Munich
# 4     474   478                       Manchester         Manchester
# 5     498   502                          Gatwick             London
# 6     503   507                         Heathrow             London
# 7     575   580                         Schiphol          Amsterdam
# 8    1195  1218                        Barcelona          Barcelona
# 9    1206  1229                          Barajas             Madrid
# 10   1358  1382                Charles De Gaulle              Paris
# 11   1529  1555                        Fiumicino               Rome
# 12   1586  1613                        Schwechat             Vienna
# 13   1673  1701                          Ataturk           Istanbul
# 14   2137  2188                       Dubai Intl              Dubai
# 15   2996  3077                   Hong Kong Intl          Hong Kong
# 16   3155  3930                     Incheon Intl              Seoul
# 17   3222  3316                      Changi Intl          Singapore
# 18   3268  3364                     Capital Intl            Beijing
# 19   3273  3370                      Baiyun Intl          Guangzhou
# 20   3298  3395                        Shuangliu            Chengdu
# 21   3307  3406                           Pudong           Shanghai
# 22   3385  3484                 Los Angeles Intl        Los Angeles
# 23   3477  3576                       Miami Intl              Miami
# 24   3571  3670           Dallas Fort Worth Intl  Dallas-Fort Worth
# 25   3583  3682  Hartsfield Jackson Atlanta Intl            Atlanta
# 26   3652  3751                      Denver Intl             Denver
# 27   3698  3797              John F Kennedy Intl           New York
# 28   3731  3830               Chicago Ohare Intl            Chicago
# 29   3777  3876           Charlotte Douglas Intl          Charlotte
# 30   3786  3885                Suvarnabhumi Intl            Bangkok
# 31   3921  4029                       Domododevo             Moscow
#
#                  country code  icao   latitude    longitude altitude offset  \
# 0                 Canada  YYZ  CYYZ  43.677223   -79.630556      569     -5
# 1                Belgium  BRU  EBBR  50.901389     4.484444      184      1
# 2                Germany  FRA  EDDF  50.026421     8.543125      364      1
# 3                Germany  MUC  EDDM  48.353783    11.786086     1487      1
# 4         United Kingdom  MAN  EGCC  53.353744     -2.27495      257      0
# 5         United Kingdom  LGW  EGKK  51.148056    -0.190278      202      0
# 6         United Kingdom  LHR  EGLL    51.4775    -0.461389       83      0
# 7            Netherlands  AMS  EHAM  52.308613     4.763889      -11      1
# 8                  Spain  BCN  LEBL  41.297078     2.078464       12      1
# 9                  Spain  MAD  LEMD  40.493556    -3.566764     2000      1
# 10                France  CDG  LFPG  49.012779         2.55      392      1
# 11                 Italy  FCO  LIRF  41.804475    12.250797       15      1
# 12               Austria  VIE  LOWW  48.110278    16.569722      600      1
# 13                Turkey  IST  LTBA  40.976922    28.814606      163      2
# 14  United Arab Emirates  DXB  OMDB  25.252778    55.364444       62      4
# 15             Hong Kong  HKG  VHHH  22.308919   113.914603       28      8
# 16           South Korea  ICN  RKSI  37.469075   126.450517       23      9
# 17             Singapore  SIN  WSSS   1.350189   103.994433       22      8
# 18                 China  PEK  ZBAA  40.080111   116.584556      116      8
# 19                 China  CAN  ZGGG  23.392436   113.298786       50      8
# 20                 China  CTU  ZUUU  30.578528   103.947086     1625      8
# 21                 China  PVG  ZSPD  31.143378   121.805214       13      8
# 22         United States  LAX  KLAX  33.942536  -118.408075      126     -8
# 23         United States  MIA  KMIA   25.79325   -80.290556        8     -5
# 24         United States  DFW  KDFW  32.896828   -97.037997      607     -6
# 25         United States  ATL  KATL  33.636719   -84.428067     1026     -5
# 26         United States  DEN  KDEN  39.861656  -104.673178     5431     -7
# 27         United States  JFK  KJFK  40.639751   -73.778925       13     -5
# 28         United States  ORD  KORD  41.978603   -87.904842      668     -6
# 29         United States  CLT  KCLT     35.214   -80.943139      748     -5
# 30              Thailand  BKK  VTBS  13.681108   100.747283        5      7
# 31                Russia  DME  UUDD  55.408611    37.906111      588      4
#
#    dst             timezone
# 0    A      America/Toronto
# 1    E      Europe/Brussels
# 2    E        Europe/Berlin
# 3    E        Europe/Berlin
# 4    E        Europe/London
# 5    E        Europe/London
# 6    E        Europe/London
# 7    E     Europe/Amsterdam
# 8    E        Europe/Madrid
# 9    E        Europe/Madrid
# 10   E         Europe/Paris
# 11   E          Europe/Rome
# 12   E        Europe/Vienna
# 13   E      Europe/Istanbul
# 14   U           Asia/Dubai
# 15   U       Asia/Hong_Kong
# 16   U           Asia/Seoul
# 17   N       Asia/Singapore
# 18   U       Asia/Chongqing
# 19   U       Asia/Chongqing
# 20   U       Asia/Chongqing
# 21   U       Asia/Chongqing
# 22   A  America/Los_Angeles
# 23   A     America/New_York
# 24   A      America/Chicago
# 25   A     America/New_York
# 26   A       America/Denver
# 27   A     America/New_York
# 28   A      America/Chicago
# 29   A     America/New_York
# 30   U         Asia/Bangkok
# 31   N        Europe/Moscow

# %% [markdown]
# #### The antijoin
#
# Just the negation of the semijoin:

# %%
# %%capture antijoin

pd.read_sql('''
SELECT *
FROM airports

WHERE NOT code IN (
SELECT source 
     FROM routes
     GROUP BY source
     HAVING COUNT(source) > 300 
)
''', con)

# %%
antijoin()
# Out:
#       index    id                               name             city  \
# 0         0     1                             Goroka           Goroka
# 1         1     2                             Madang           Madang
# 2         2     3                        Mount Hagen      Mount Hagen
# 3         3     4                             Nadzab           Nadzab
# 4         4     5         Port Moresby Jacksons Intl     Port Moresby
# ...     ...   ...                                ...              ...
# 5843   8102  9537    Mansons Landing Water Aerodrome  Mansons Landing
# 5844   8103  9538               Port McNeill Airport     Port McNeill
# 5845   8104  9539       Sullivan Bay Water Aerodrome     Sullivan Bay
# 5846   8105  9540               Deer Harbor Seaplane      Deer Harbor
# 5847   8106  9541  San Diego Old Town Transit Center        San Diego
#
#                country code  icao   latitude    longitude altitude offset dst  \
# 0     Papua New Guinea  GKA  AYGA  -6.081689   145.391881     5282     10   U
# 1     Papua New Guinea  MAG  AYMD  -5.207083     145.7887       20     10   U
# 2     Papua New Guinea  HGU  AYMH  -5.826789   144.295861     5388     10   U
# 3     Papua New Guinea  LAE  AYNZ  -6.569828   146.726242      239     10   U
# 4     Papua New Guinea  POM  AYPY  -9.443383    147.22005      146     10   U
# ...                ...  ...   ...        ...          ...      ...    ...  ..
# 5843            Canada  YMU    \N  50.066667  -124.983333        0     -8   A
# 5844            Canada  YMP    \N  50.575556  -127.028611      225     -8   A
# 5845            Canada  YTG    \N  50.883333  -126.833333        0     -8   A
# 5846     United States  DHB    \N  48.618397   -123.00596        0     -8   A
# 5847     United States  OLT    \N    32.7552    -117.1995        0     -8   A
#
#                   timezone
# 0     Pacific/Port_Moresby
# 1     Pacific/Port_Moresby
# 2     Pacific/Port_Moresby
# 3     Pacific/Port_Moresby
# 4     Pacific/Port_Moresby
# ...                    ...
# 5843     America/Vancouver
# 5844     America/Vancouver
# 5845     America/Vancouver
# 5846   America/Los_Angeles
# 5847   America/Los_Angeles
#
# [5848 rows x 13 columns]

# %% [markdown]
# #### Subqueries in the SELECT statement
#
# Get altitude of airport side by side with average airport altitude in the respective country.

# %%
# %%capture select_subquery

pd.read_sql('''
SELECT country,
name, 
CAST(altitude as int) AS altitude ,

(SELECT AVG(CAST(altitude as int))
FROM airports
GROUP BY 
country) AS avg_alt

FROM airports


''', con)

# %%
select_subquery()
# Out:
#                country                               name  altitude  \
# 0     Papua New Guinea                             Goroka      5282
# 1     Papua New Guinea                             Madang        20
# 2     Papua New Guinea                        Mount Hagen      5388
# 3     Papua New Guinea                             Nadzab       239
# 4     Papua New Guinea         Port Moresby Jacksons Intl       146
# ...                ...                                ...       ...
# 8102            Canada    Mansons Landing Water Aerodrome         0
# 8103            Canada               Port McNeill Airport       225
# 8104            Canada       Sullivan Bay Water Aerodrome         0
# 8105     United States               Deer Harbor Seaplane         0
# 8106     United States  San Diego Old Town Transit Center         0
#
#           avg_alt
# 0     3750.809524
# 1     3750.809524
# 2     3750.809524
# 3     3750.809524
# 4     3750.809524
# ...           ...
# 8102  3750.809524
# 8103  3750.809524
# 8104  3750.809524
# 8105  3750.809524
# 8106  3750.809524
#
# [8107 rows x 4 columns]

# %% [markdown]
# #### Common Table Expressions (CTEs)
#
# Useful for when:
#
# - Multiple subqueries floating around.
# - Reusing same subqueries over and over again in same statement.
#
# Cleans code up, reduces error, makes readable.

# %% [markdown]
# CTE syntax:
#
# WITH subquery1_name AS (subquery1 statement),
# <br>
# WITH subquery2_name AS (subquery2 statement),
# <br>
# ....,
# <br>
# WITH subquery_n_name AS (subquery_n statement)
# <br>
# <br>
# MAIN QUERY

# %%
# %%capture filtered_result

pd.read_sql("""

WITH s1 AS (
     SELECT source, COUNT(source) as departure_count
     FROM routes
     GROUP BY source),
     
     s2 AS ( 
     SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     GROUP BY dest
     )


SELECT source, departure_count, arrival_count
FROM
s1 INNER JOIN s2
ON s1.source = s2.dest

     
""", con)

# %%
filtered_result()
# Out:
#      source  departure_count  arrival_count
# 0       AAE                9              9
# 1       AAL               20             21
# 2       AAN                2              2
# 3       AAQ                3              3
# 4       AAR                8              8
# ...     ...              ...            ...
# 3397    ZUH               60             59
# 3398    ZUM                2              2
# 3399    ZVK                3              3
# 3400    ZYI               15             15
# 3401    ZYL                4              6
#
# [3402 rows x 3 columns]

# %% [markdown]
# CTEs make the primary query easy to read.
#
# - Subqueries can just be referenced by looking it up in the CTE.
