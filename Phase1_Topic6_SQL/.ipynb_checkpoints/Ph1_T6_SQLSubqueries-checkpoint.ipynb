# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# SQL: Subqueries
#
# </p>
# </div>
#
# Data Science Cohort Live NYC Feb 2022
# <p>Phase 1: Topic 6</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="Images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %% [markdown]
# Queries can get complex:
# - Helpful/necessary to build a query out of sub-units
# - These subunits are queries which might include:
#     - groupbys/agg functions
#     - selecting/filtering
#     - etc.

# %% [markdown]
# <img src = "Images/sql_subquery.jpg">

# %% [markdown]
# Inner query is a **subquery**:
#
# - Generates an intermediate table that stores results temporarily in memory.
# - Subquery intermediate table can be used during execution of main query.

# %% [markdown]
# Subqueries can be used to great effect in a variety of circumstances:
#
# - Selecting from a table created by a subquery
#     - Subquery in FROM statement
# - Filtering on a subquery.
#     - Subquery in a WHERE statement
# - Filtering in a SELECT statement.

# %% [markdown]
# #### Subquery in FROM clause

# %% [markdown]
# First load our handy dandy flights database.

# %%
import sqlite3
import numpy as np
import pandas as pd

# connect to flights database
con = sqlite3.connect('data/flights.db')

# %% [markdown]
# Recall the various tables in flight database:

# %%
# %%bash
#
# sqlite3 data/flights.db
# .tables
# Out:
# airlines  airports  routes

# %%
pd.read_sql("""

SELECT * 
FROM airports
LIMIT 2

""", con)
# Out:
#    index id    name    city           country code  icao   latitude  \
# 0      0  1  Goroka  Goroka  Papua New Guinea  GKA  AYGA  -6.081689
# 1      1  2  Madang  Madang  Papua New Guinea  MAG  AYMD  -5.207083
#
#     longitude altitude offset dst              timezone
# 0  145.391881     5282     10   U  Pacific/Port_Moresby
# 1    145.7887       20     10   U  Pacific/Port_Moresby

# %% [markdown]
# #### Problem
#
# Get the average altitude of the highest altitude airports in the United States, Russia, and China.
#
# Useful to break this into steps with a subquery.

# %% [markdown]
# - First filter airports on country.
# - Then group by country and aggregate.
# - Get average of the altitudes of the resultant airports.
#
# Step by step.
#
# Can also control execution flow and number of operations in a query this way.

# %% [markdown]
# Step 1: Filter airports on relevant countries.

# %%
sq1 = pd.read_sql("""

SELECT 

FROM

     

""", con)

# %%
sq1

# %% [markdown]
# Step 2: Use filtered table (via subquery) and get max altitude airport by country
#
# Want: name, city, altitude of these airports

# %%
sq2 = pd.read_sql("""

SELECT 
     
FROM 

(SELECT *
FROM airports 
WHERE country IN 
("United States", "Russia", "China") ) AS cf


     

""", con)

# %% [markdown]
# - Subquery in parentheses for defining temporary table
# - Aliasing subquery:
#     - good practice
#     - ease of referencing subquery fields in main query

# %%
sq2
# Out:
#               name       city        country  max_altitude
# 0  Yading Daocheng   Daocheng          China       14472.0
# 1        Irkutsk-2    Irkutsk         Russia       13411.0
# 2        Silverton  Silverton  United States        9308.0

# %% [markdown]
# Now get the mean altitude across the three countries:

# %%
sq3 = pd.read_sql("""

SELECT AVG(max_altitude) 
AS max_altitude_avg
    
FROM 

(
SELECT name, 
     city,
     country,
     MAX(CAST(altitude as float)) 
     AS max_altitude

FROM 

(SELECT *
FROM airports 
WHERE country IN 
("United States", "Russia", "China") ) AS cf
GROUP BY cf.country
)

     

""", con)

# %%
sq3
# Out:
#    max_altitude_avg
# 0           12397.0

# %% [markdown]
# Two levels of subqueries gets the job done.

# %% [markdown]
# #### Using derived tables in joins
#
# - create set of tables from subqueries
# - use these to create a new table with derived columns from subqueries.
#
# Let's take a simple (somewhat artificial example) of this.

# %% [markdown]
# For each airport I want:
# - the count of routes that leaves from an airport.
# - the count of routes that arrive there.
#
# Many ways to do this. But I'll make full use of subqueries and joins here.

# %%
pd.read_sql("""

SELECT * 
     FROM routes
     LIMIT 5


""", con)
# Out:
#    index airline airline_id source source_id dest dest_id codeshare stops  \
# 0      0      2B        410    AER      2965  KZN    2990      None     0
# 1      1      2B        410    ASF      2966  KZN    2990      None     0
# 2      2      2B        410    ASF      2966  MRV    2962      None     0
# 3      3      2B        410    CEK      2968  KZN    2990      None     0
# 4      4      2B        410    CEK      2968  OVB    4078      None     0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# First calculate count of routes departing from each airport.

# %%
departure_table = pd.read_sql("""


     
""", con)

# %%
departure_table = pd.read_sql("""

SELECT source, COUNT(source) as departure_count
     FROM routes
     
     GROUP BY source
     
""", con)

# %%
departure_table
# Out:
#      source  departure_count
# 0       AAE                9
# 1       AAL               20
# 2       AAN                2
# 3       AAQ                3
# 4       AAR                8
# ...     ...              ...
# 3404    ZUH               60
# 3405    ZUM                2
# 3406    ZVK                3
# 3407    ZYI               15
# 3408    ZYL                4
#
# [3409 rows x 2 columns]

# %%
arrival_table = pd.read_sql("""

SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     
     GROUP BY dest
     
""", con)

# %%
arrival_table
# Out:
#      dest  arrival_count
# 0     AAE              9
# 1     AAL             21
# 2     AAN              2
# 3     AAQ              3
# 4     AAR              8
# ...   ...            ...
# 3413  ZUH             59
# 3414  ZUM              2
# 3415  ZVK              3
# 3416  ZYI             15
# 3417  ZYL              6
#
# [3418 rows x 2 columns]

# %% [markdown]
# We can link these the arrival tables and destination tables together:
# - Keep records where source and destination are in both tables.
# - What operation?

# %% [markdown]
# INNER JOIN ON SUBQUERY RESULTS!

# %%
# %%capture full_result

pd.read_sql("""

SELECT dep.source AS airport_code,
        dep.departure_count,
        arriv.arrival_count 
        
FROM

(SELECT source, COUNT(source) as departure_count
     FROM routes
     
     GROUP BY source) AS dep

INNER JOIN 

(SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     
     GROUP BY dest) AS arriv

ON dep.source = arriv.dest
     
""", con)

# %%
full_result()
# Out:
#      airport_code  departure_count  arrival_count
# 0             AAE                9              9
# 1             AAL               20             21
# 2             AAN                2              2
# 3             AAQ                3              3
# 4             AAR                8              8
# ...           ...              ...            ...
# 3397          ZUH               60             59
# 3398          ZUM                2              2
# 3399          ZVK                3              3
# 3400          ZYI               15             15
# 3401          ZYL                4              6
#
# [3402 rows x 3 columns]

# %% [markdown]
# This result is a derived table telling us information for each airport and keeping relevant records.
#
# - We can filter or aggregate on this derived table as we see fit.
#
#
# - Get all airports with significance difference in:
#     - number of routes originating and terminating at given airport.
#     - dfference in departure and arrival route counts greater than 5.
# - Order in descending order of this difference.
#
# Help this hapless data science instructor out!

# %%
# %%capture filtered_result

pd.read_sql("""

SELECT dep.source AS airport_code,
        dep.departure_count,
        arriv.arrival_count
        
FROM

(SELECT source, COUNT(source) as departure_count
     FROM routes
     
     GROUP BY source) AS dep

INNER JOIN 

(SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     
     GROUP BY dest) AS arriv

ON dep.source = arriv.dest


     
""", con)

# %%
# %%capture filtered_result

pd.read_sql("""

SELECT dep.source AS airport_code,
        dep.departure_count,
        arriv.arrival_count, 
        ABS(dep.departure_count - arrival_count) AS count_diff
        
FROM

(SELECT source, COUNT(source) as departure_count
     FROM routes
     
     GROUP BY source) AS dep

INNER JOIN 

(SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     
     GROUP BY dest) AS arriv

ON dep.source = arriv.dest

WHERE count_diff > 3
ORDER BY count_diff DESC
     
""", con)

# %%
filtered_result()
# Out:
#    airport_code  departure_count  arrival_count  count_diff
# 0           AKL               96            117          21
# 1           MED               39             59          20
# 2           PWM                2             18          16
# 3           DEN              361            374          13
# 4           JED              194            183          11
# 5           ATH              197            206           9
# 6           CRW                6             15           9
# 7           HOU               79             70           9
# 8           YHZ               43             52           9
# 9           BNE              152            144           8
# 10          MUC              368            360           8
# 11          ORD              558            550           8
# 12          CDG              524            517           7
# 13          LIS              214            221           7
# 14          MDW              139            132           7
# 15          MRS              136            129           7
# 16          STL              114            107           7
# 17          IAD              196            190           6
# 18          JIB               23             17           6
# 19          LAS              246            252           6
# 20          LAX              492            498           6
# 21          MSP              218            212           6
# 22          PHX              251            257           6
# 23          PMI              271            277           6
# 24          SYD              208            202           6
# 25          ADQ               11              6           5
# 26          AUH              241            236           5
# 27          HRE               26             31           5
# 28          LYS              135            140           5
# 29          MAN              316            311           5
# 30          MCI               82             77           5
# 31          MEL              137            132           5
# 32          MKE               65             60           5
# 33          SID               20             15           5
# 34          TLS               78             83           5
# 35          ADD              105            109           4
# 36          ATL              915            911           4
# 37          BKK              326            330           4
# 38          BVC               12             16           4
# 39          CHC               34             38           4
# 40          DCA              196            192           4
# 41          DLA               51             47           4
# 42          DWC               48             44           4
# 43          FRA              497            493           4
# 44          GLA              100             96           4
# 45          HKT               71             67           4
# 46          IBZ               99            103           4
# 47          KGS               43             47           4
# 48          LCA               93             97           4
# 49          LCY               62             66           4
# 50          LGW              356            352           4
# 51          MEM               58             54           4
# 52          MGQ               10             14           4
# 53          NSI               17             21           4
# 54          PDX              113            117           4
# 55          RHO               82             86           4
# 56          SIN              408            412           4
# 57          SLC              141            137           4
# 58          UNK                8             12           4

# %% [markdown]
# - Complex as subqueries pile on.
# - There are ways to organize subqueries: common table expressions
# - Will make code readable.
#
# But first: other ways subqueries can be used.

# %% [markdown]
# #### Subqueries in the WHERE statement
#
# - Can use the result of a subquery to filter another selection.
# - Particularly useful when you want to filter on the results of:
#     - groupbys, etc
#     - results from other tables
#
# I want all route records where the departure airport has a departure route count greater than 200.

# %%
# %%capture where_subquery1
pd.read_sql('''


SELECT *
            
FROM routes

WHERE source IN (SELECT source 
     FROM routes
     GROUP BY source
     HAVING COUNT(source) > 200) 
''', con)

# %%
where_subquery1()
# Out:
#        index airline airline_id source source_id dest dest_id codeshare stops  \
# 0          5      2B        410    DME      4029  KZN    2990      None     0
# 1          6      2B        410    DME      4029  NBC    6969      None     0
# 2          7      2B        410    DME      4029  TGK      \N      None     0
# 3          8      2B        410    DME      4029  UUA    6160      None     0
# 4        123      2L       2750    ZRH      1678  BDS    1506      None     0
# ...      ...     ...        ...    ...       ...  ...     ...       ...   ...
# 21698  67646      ZL       4178    SYD      3361  OAG    6793      None     0
# 21699  67647      ZL       4178    SYD      3361  PKE    6317      None     0
# 21700  67648      ZL       4178    SYD      3361  TRO    6794      None     0
# 21701  67649      ZL       4178    SYD      3361  WGA    3363      None     0
# 21702  67659      ZM      19016    DME      4029  FRU    2912      None     0
#
#       equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           100
# ...         ...
# 21698       SF3
# 21699       SF3
# 21700       SF3
# 21701       SF3
# 21702       734
#
# [21703 rows x 10 columns]

# %% [markdown]
# Subqueries made this selection possible.

# %% [markdown]
# #### The Semijoin
#
# - Using a subquery from one table to filter another table.
#
# Example:
#
# Get the airport name, code, country, and altitude for airports with more than 200 routes originating from that airport.

# %%
# %%capture semijoin
pd.read_sql('''

SELECT name, code, country, 
CAST(altitude AS int) AS altitde
FROM airports

WHERE code IN (
SELECT source
     FROM routes
     GROUP BY source
     HAVING COUNT(source) > 300 
)
''', con)

# %%
semijoin()
# Out:
#                                name code               country  altitde
# 0             Lester B Pearson Intl  YYZ                Canada      569
# 1                     Brussels Natl  BRU               Belgium      184
# 2                    Frankfurt Main  FRA               Germany      364
# 3               Franz Josef Strauss  MUC               Germany     1487
# 4                        Manchester  MAN        United Kingdom      257
# 5                           Gatwick  LGW        United Kingdom      202
# 6                          Heathrow  LHR        United Kingdom       83
# 7                          Schiphol  AMS           Netherlands      -11
# 8                         Barcelona  BCN                 Spain       12
# 9                           Barajas  MAD                 Spain     2000
# 10                Charles De Gaulle  CDG                France      392
# 11                        Fiumicino  FCO                 Italy       15
# 12                        Schwechat  VIE               Austria      600
# 13                          Ataturk  IST                Turkey      163
# 14                       Dubai Intl  DXB  United Arab Emirates       62
# 15                   Hong Kong Intl  HKG             Hong Kong       28
# 16                     Incheon Intl  ICN           South Korea       23
# 17                      Changi Intl  SIN             Singapore       22
# 18                     Capital Intl  PEK                 China      116
# 19                      Baiyun Intl  CAN                 China       50
# 20                        Shuangliu  CTU                 China     1625
# 21                           Pudong  PVG                 China       13
# 22                 Los Angeles Intl  LAX         United States      126
# 23                       Miami Intl  MIA         United States        8
# 24           Dallas Fort Worth Intl  DFW         United States      607
# 25  Hartsfield Jackson Atlanta Intl  ATL         United States     1026
# 26                      Denver Intl  DEN         United States     5431
# 27              John F Kennedy Intl  JFK         United States       13
# 28               Chicago Ohare Intl  ORD         United States      668
# 29           Charlotte Douglas Intl  CLT         United States      748
# 30                Suvarnabhumi Intl  BKK              Thailand        5
# 31                       Domododevo  DME                Russia      588

# %% [markdown]
# #### The antijoin
#
# Just the negation of the semijoin:

# %%
# %%capture antijoin

pd.read_sql('''
SELECT *
FROM airports

WHERE NOT code IN (
SELECT source 
     FROM routes
     GROUP BY source
     HAVING COUNT(source) > 300 
)
''', con)

# %%
antijoin()
# Out:
#       index    id                               name             city  \
# 0         0     1                             Goroka           Goroka
# 1         1     2                             Madang           Madang
# 2         2     3                        Mount Hagen      Mount Hagen
# 3         3     4                             Nadzab           Nadzab
# 4         4     5         Port Moresby Jacksons Intl     Port Moresby
# ...     ...   ...                                ...              ...
# 5843   8102  9537    Mansons Landing Water Aerodrome  Mansons Landing
# 5844   8103  9538               Port McNeill Airport     Port McNeill
# 5845   8104  9539       Sullivan Bay Water Aerodrome     Sullivan Bay
# 5846   8105  9540               Deer Harbor Seaplane      Deer Harbor
# 5847   8106  9541  San Diego Old Town Transit Center        San Diego
#
#                country code  icao   latitude    longitude altitude offset dst  \
# 0     Papua New Guinea  GKA  AYGA  -6.081689   145.391881     5282     10   U
# 1     Papua New Guinea  MAG  AYMD  -5.207083     145.7887       20     10   U
# 2     Papua New Guinea  HGU  AYMH  -5.826789   144.295861     5388     10   U
# 3     Papua New Guinea  LAE  AYNZ  -6.569828   146.726242      239     10   U
# 4     Papua New Guinea  POM  AYPY  -9.443383    147.22005      146     10   U
# ...                ...  ...   ...        ...          ...      ...    ...  ..
# 5843            Canada  YMU    \N  50.066667  -124.983333        0     -8   A
# 5844            Canada  YMP    \N  50.575556  -127.028611      225     -8   A
# 5845            Canada  YTG    \N  50.883333  -126.833333        0     -8   A
# 5846     United States  DHB    \N  48.618397   -123.00596        0     -8   A
# 5847     United States  OLT    \N    32.7552    -117.1995        0     -8   A
#
#                   timezone
# 0     Pacific/Port_Moresby
# 1     Pacific/Port_Moresby
# 2     Pacific/Port_Moresby
# 3     Pacific/Port_Moresby
# 4     Pacific/Port_Moresby
# ...                    ...
# 5843     America/Vancouver
# 5844     America/Vancouver
# 5845     America/Vancouver
# 5846   America/Los_Angeles
# 5847   America/Los_Angeles
#
# [5848 rows x 13 columns]

# %% [markdown]
# #### Subqueries in the SELECT statement
#
# Get altitude of airport side by side with average airport altitude in the respective country.

# %%
# %%capture select_subquery

pd.read_sql('''
SELECT a1.country,
name, 
CAST(altitude as int) AS altitude ,

(SELECT AVG(CAST(altitude as int))
FROM airports AS a2
WHERE a2.country == a1.country
) AS avg_alt

FROM airports AS a1


''', con)

# %% [markdown]
# Sometimes known as a **correlated subquery**.
#
# - Inner select statement filters a2 by country matching a given row's country in a1. Takes average altitude.
#
# - Does this for each row in a1. The filtering of a2 by country *correlated* with current row in a1.
#
#
# **Correlated subqueries can be a bit slow**

# %%
select_subquery()
# Out:
#                country                               name  altitude  \
# 0     Papua New Guinea                             Goroka      5282
# 1     Papua New Guinea                             Madang        20
# 2     Papua New Guinea                        Mount Hagen      5388
# 3     Papua New Guinea                             Nadzab       239
# 4     Papua New Guinea         Port Moresby Jacksons Intl       146
# ...                ...                                ...       ...
# 8102            Canada    Mansons Landing Water Aerodrome         0
# 8103            Canada               Port McNeill Airport       225
# 8104            Canada       Sullivan Bay Water Aerodrome         0
# 8105     United States               Deer Harbor Seaplane         0
# 8106     United States  San Diego Old Town Transit Center         0
#
#          avg_alt
# 0     852.982456
# 1     852.982456
# 2     852.982456
# 3     852.982456
# 4     852.982456
# ...          ...
# 8102  773.326437
# 8103  773.326437
# 8104  773.326437
# 8105  951.795522
# 8106  951.795522
#
# [8107 rows x 4 columns]

# %% [markdown]
# #### Common Table Expressions (CTEs)
#
# Useful for when:
#
# - Multiple subqueries floating around.
# - Reusing same subqueries over and over again in same statement.
#
# Cleans code up, reduces error, makes readable.

# %% [markdown]
# CTE syntax:
#
# WITH subquery1_name AS (subquery1 statement),
# <br>
# WITH subquery2_name AS (subquery2 statement),
# <br>
# ....,
# <br>
# WITH subquery_n_name AS (subquery_n statement)
# <br>
# <br>
# MAIN QUERY

# %%
# %%capture filtered_result

pd.read_sql("""

WITH s1 AS (
     SELECT source, COUNT(source) as departure_count
     FROM routes
     GROUP BY source),
     
     s2 AS ( 
     SELECT dest, COUNT(dest) as arrival_count
     FROM routes
     GROUP BY dest
     )


SELECT source, departure_count, arrival_count
FROM
s1 INNER JOIN s2
ON s1.source = s2.dest

     
""", con)

# %%
filtered_result()
# Out:
#      source  departure_count  arrival_count
# 0       AAE                9              9
# 1       AAL               20             21
# 2       AAN                2              2
# 3       AAQ                3              3
# 4       AAR                8              8
# ...     ...              ...            ...
# 3397    ZUH               60             59
# 3398    ZUM                2              2
# 3399    ZVK                3              3
# 3400    ZYI               15             15
# 3401    ZYL                4              6
#
# [3402 rows x 3 columns]

# %% [markdown]
# CTEs make the primary query easy to read.
#
# - Subqueries can just be referenced by looking it up in the CTE.

# %%
df3 = pd.read_sql("""

SELECT source, dest,
ap1.city AS source_city,
ap2.city AS dest_city,
ap1.country AS source_country, 
ap2.country AS dest_country,
CAST(ap1.altitude as float) AS alt,
max_alt

FROM routes
INNER JOIN 

(
SELECT * 
FROM
airports
WHERE country == 'United States') as ap1


INNER JOIN 

(
SELECT country, 
city, name, code, 
MAX(CAST(altitude as float)) AS max_alt

FROM airports 
GROUP BY country
)  as ap2

ON (routes.source == ap1.code AND routes.dest == ap2.code)

""", con)
