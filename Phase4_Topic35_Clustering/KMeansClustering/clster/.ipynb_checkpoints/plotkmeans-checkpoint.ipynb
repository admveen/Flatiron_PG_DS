# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
kmeans_centroids = np.genfromtxt('centroids-50.csv', delimiter =",")
X_kmeans, Y_kmeans = kmeans_centroids.T

# %%
plt.scatter(X_kmeans, Y_kmeans, c = 'red', s = 80)
